# %%
text_filter=[
    {"name":"tr_euronews",
     "READER":{"total":261840, "doc_len":{"min":159, "max":1007987, "avg":161135}},
     "EXTRAC":{"total": 262103, "forwarded": 256696,"dropped": 5399, "doc_len": {"min":18, "max":852181, "avg":1720}},
     "Gopher Repetition":{"total": 256696, "forwarded": 221327, "dropped": 35369, "doc_len": {"min":101, "max":852028, "avg":1821}, "dropped_duplicated_9_n_grams": 3921, "dropped_dup_line_frac": 7361, "dropped_duplicated_5_n_grams": 7809, "dropped_duplicated_10_n_grams": 4338, "dropped_duplicated_8_n_grams": 2507, "dropped_duplicated_6_n_grams": 2552, "dropped_duplicated_7_n_grams": 2413, "dropped_dup_line_char_frac": 1205, "dropped_top_4_gram": 1919, "dropped_top_2_gram": 195, "dropped_top_3_gram": 1149},
     "Gopher Quality":{"total": 221327, "forwarded": 169735, "dropped": 51592, "doc_len": {"min":312, "max":45075, "avg":2196}, "dropped_gopher_short_doc": 10410, "dropped_gopher_below_alpha_threshold": 34199, "dropped_gopher_too_many_end_ellipsis": 98, "dropped_gopher_enough_stop_words": 6869, "dropped_gopher_above_avg_threshold": 5, "dropped_gopher_too_many_bullets": 7, "dropped_gopher_too_many_hashes": 3, "dropped_gopher_too_many_ellipsis": 1},
     "FineWeb Quality": {"total": 169735, "forwarded": 131181, "dropped": 38554, "doc_len": {"min":312, "max":45075, "avg":1769}, "dropped_char_dup_ratio": 16528, "dropped_line_punct_ratio": 21990, "dropped_short_line_ratio": 36},
     "WRITER":{"total": 131181, "doc_len": {"min":312, "max":45075, "avg":1769}}
     },
    {"name":"ajltr",
     "READER":{"total":8007, "doc_len":{"min":15073, "max":135270, "avg":27552}},
     "EXTRAC":{"total": 8016, "forwarded": 7894,"dropped": 122, "doc_len": {"min":104, "max":104844, "avg":3660}},
     "Gopher Repetition":{"total": 7894, "forwarded": 7786, "dropped": 108, "doc_len": {"min":112, "max":46702, "avg":3675}, "dropped_top_4_gram": 22, "dropped_top_3_gram": 7, "dropped_duplicated_5_n_grams": 23, "dropped_dup_line_frac": 40, "dropped_dup_line_char_frac": 2, "dropped_duplicated_9_n_grams": 5, "dropped_duplicated_8_n_grams": 3, "dropped_duplicated_10_n_grams": 3, "dropped_duplicated_6_n_grams": 2, "dropped_duplicated_7_n_grams": 1},
     "Gopher Quality":{"total": 7786, "forwarded": 6892, "dropped": 894, "doc_len": {"min":340, "max":46702, "avg":4063}, "dropped_gopher_short_doc": 505, "dropped_gopher_below_alpha_threshold": 39, "dropped_gopher_too_many_end_ellipsis": 320, "dropped_gopher_enough_stop_words": 30},
     "FineWeb Quality": {"total": 6892, "forwarded": 6707, "dropped": 185, "doc_len": {"min":340, "max":46702, "avg":4097}, "dropped_line_punct_ratio": 118, "dropped_char_dup_ratio": 63, "dropped_short_line_ratio": 4},
     "WRITER":{"total": 6707, "doc_len": {"min":340, "max":46702, "avg":4097}}
     },
    {"name":"t24",
     "READER":{"total":447961, "doc_len":{"min":1372, "max":614991, "avg":21556}},
     "EXTRAC":{"total": 448410, "forwarded": 443140,"dropped": 2797, "doc_len": {"min":20, "max":300230, "avg":2343}},
     "Gopher Repetition":{"total": 443140, "forwarded": 381705, "dropped": 61435, "doc_len": {"min":102, "max":300230, "avg":2502}, "dropped_duplicated_5_n_grams": 24572, "dropped_duplicated_7_n_grams": 4042, "dropped_duplicated_8_n_grams": 4383, "dropped_duplicated_6_n_grams": 4325, "dropped_dup_line_frac": 6398, "dropped_top_3_gram": 1250, "dropped_duplicated_10_n_grams": 6153, "dropped_duplicated_9_n_grams": 5259, "dropped_top_4_gram": 4011, "dropped_dup_line_char_frac": 861, "dropped_top_2_gram": 181},
     "Gopher Quality":{"total": 381705, "forwarded": 304176, "dropped": 77529, "doc_len": {"min":291, "max":300230, "avg":2893}, "dropped_gopher_short_doc": 27968, "dropped_gopher_too_many_end_ellipsis": 30984, "dropped_gopher_enough_stop_words": 3974, "dropped_gopher_too_many_bullets": 11095, "dropped_gopher_below_alpha_threshold": 3473, "dropped_gopher_too_many_ellipsis": 29, "dropped_gopher_above_avg_threshold": 4, "dropped_gopher_below_avg_threshold": 1, "dropped_gopher_too_many_hashes": 1},
     "FineWeb Quality": {"total": 304176, "forwarded": 273183, "dropped": 30993, "doc_len": {"min":291, "max":300230, "avg":2886}, "dropped_line_punct_ratio": 15620, "dropped_char_dup_ratio": 14551, "dropped_short_line_ratio": 822},
     "WRITER":{"total": 273183, "doc_len": {"min":291, "max":300230, "avg":2886}}
     },
   {"name":"cnnturk",
     "READER":{"total":519283, "doc_len":{"min":297, "max":828096, "avg":105458}},
     "EXTRAC":{"total": 519805, "forwarded": 504825,"dropped": 14980, "doc_len": {"min":33, "max":128995, "avg":1781}},
     "Gopher Repetition":{"total": 504825, "forwarded": 442128, "dropped": 62697, "doc_len": {"min":103, "max":128995, "avg":1829}, "dropped_dup_line_frac": 26321, "dropped_duplicated_10_n_grams": 3681, "dropped_duplicated_5_n_grams": 13941, "dropped_duplicated_8_n_grams": 2056, "dropped_duplicated_7_n_grams": 2086, "dropped_top_4_gram": 3544, "dropped_duplicated_6_n_grams": 2260, "dropped_duplicated_9_n_grams": 2255, "dropped_top_3_gram": 3246, "dropped_dup_line_char_frac": 1491, "dropped_top_2_gram": 1816},
     "Gopher Quality":{"total": 442128, "forwarded": 401620, "dropped": 40508, "doc_len": {"min":310, "max":128995, "avg":1938}, "dropped_gopher_too_many_end_ellipsis": 2444, "dropped_gopher_short_doc": 17868, "dropped_gopher_below_alpha_threshold": 9944, "dropped_gopher_enough_stop_words": 8539, "dropped_gopher_too_many_bullets": 216, "dropped_gopher_too_many_ellipsis": 1487, "dropped_gopher_below_avg_threshold": 2, "dropped_gopher_too_many_hashes": 3, "dropped_gopher_above_avg_threshold": 5},
     "FineWeb Quality": {"total": 401620, "forwarded": 383255, "dropped": 18365, "doc_len": {"min":310, "max":128995, "avg":1917}, "dropped_char_dup_ratio": 10055, "dropped_line_punct_ratio": 7171, "dropped_short_line_ratio": 1139},
     "WRITER":{"total": 383255, "doc_len": {"min":310, "max":128995, "avg":1917}}
     },
        
   {"name":"dwtr",
     "READER":{"total":82231, "doc_len":{"min":995, "max":151058, "avg":39253}},
     "EXTRAC":{"total": 82314, "forwarded": 82289,"dropped": 25, "doc_len": {"min":96, "max":37211, "avg":2771}},
     "Gopher Repetition":{"total": 82289, "forwarded": 81400, "dropped": 889, "doc_len": {"min":113, "max":31179, "avg":2768}, "dropped_dup_line_frac": 440, "dropped_duplicated_9_n_grams": 27, "dropped_duplicated_10_n_grams": 23, "dropped_duplicated_5_n_grams": 32, "dropped_top_4_gram": 266, "dropped_top_3_gram": 46, "dropped_duplicated_7_n_grams": 10, "dropped_duplicated_8_n_grams": 21, "dropped_dup_line_char_frac": 10, "dropped_duplicated_6_n_grams": 9, "dropped_top_2_gram": 5},
     "Gopher Quality":{"total": 81400, "forwarded": 78690, "dropped": 2710, "doc_len": {"min":326, "max":31179, "avg":2846}, "dropped_gopher_too_many_end_ellipsis": 58, "dropped_gopher_below_alpha_threshold": 156, "dropped_gopher_short_doc": 2247, "dropped_gopher_enough_stop_words": 247, "dropped_gopher_too_many_bullets": 1, "dropped_gopher_below_avg_threshold": 1},
     "FineWeb Quality": {"total": 78690, "forwarded": 75902, "dropped": 2788, "doc_len": {"min":326, "max":31179, "avg":2830}, "dropped_line_punct_ratio": 2364, "dropped_char_dup_ratio": 191, "dropped_short_line_ratio": 233},
     "WRITER":{"total": 75902, "doc_len": {"min":326, "max":31179, "avg":2830}}
     },
   
   {"name":"sozcu",
     "READER":{"total":82231, "doc_len":{"min":545, "max":1050830, "avg":24466}},
     "EXTRAC":{"total": 489965, "forwarded": 482092,"dropped": 7869, "doc_len": {"min":93, "max":505306, "avg":1995}},
     "Gopher Repetition":{"total": 482092, "forwarded": 464659, "dropped": 17433, "doc_len": {"min":101, "max":485855, "avg":1979}, "dropped_duplicated_5_n_grams": 5956, "dropped_dup_line_frac": 3575, "dropped_duplicated_6_n_grams": 866, "dropped_duplicated_9_n_grams": 874, "dropped_duplicated_10_n_grams": 1016, "dropped_duplicated_7_n_grams": 712, "dropped_duplicated_8_n_grams": 727, "dropped_top_4_gram": 2331, "dropped_dup_line_char_frac": 534, "dropped_top_3_gram": 722, "dropped_top_2_gram": 120},
     "Gopher Quality":{"total": 464659, "forwarded": 424728, "dropped": 39931, "doc_len": {"min":290, "max":244312, "avg":2080}, "dropped_gopher_short_doc": 21497, "dropped_gopher_below_alpha_threshold": 5746, "dropped_gopher_enough_stop_words": 3996, "dropped_gopher_too_many_end_ellipsis": 8236, "dropped_gopher_too_many_ellipsis": 416, "dropped_gopher_too_many_bullets": 31, "dropped_gopher_above_avg_threshold": 7, "dropped_gopher_too_many_hashes": 2},
     "FineWeb Quality": {"total": 424728, "forwarded": 410445, "dropped": 14283, "doc_len": {"min":290, "max":106482, "avg":2066}, "dropped_short_line_ratio": 4036, "dropped_line_punct_ratio": 6692, "dropped_char_dup_ratio": 3555},
     "WRITER":{"total": 410445, "doc_len": {"min":290, "max":106482, "avg":2066}}
     },
   
   {"name":"yesil",
     "READER":{"total":115393, "doc_len":{"min":39024, "max":904316, "avg":78376}},
     "EXTRAC":{"total": 115509, "forwarded": 114445,"dropped": 1064, "doc_len": {"min":11, "max":141634, "avg":2174}},
     "Gopher Repetition":{"total": 114445, "forwarded": 76190, "dropped": 38255, "doc_len": {"min":132, "max":141634, "avg":2940}, "dropped_duplicated_5_n_grams": 2859, "dropped_duplicated_7_n_grams": 1652, "dropped_duplicated_10_n_grams": 1232, "dropped_dup_line_frac": 28791, "dropped_top_4_gram": 542, "dropped_duplicated_8_n_grams": 588, "dropped_top_3_gram": 186, "dropped_duplicated_9_n_grams": 645, "dropped_duplicated_6_n_grams": 173, "dropped_dup_line_char_frac": 1573, "dropped_top_2_gram": 14},
     "Gopher Quality":{"total": 76190, "forwarded": 57863, "dropped": 18327, "doc_len": {"min":320, "max":141634, "avg":3593}, "dropped_gopher_too_many_end_ellipsis": 12096, "dropped_gopher_short_doc": 5523, "dropped_gopher_below_alpha_threshold": 471, "dropped_gopher_enough_stop_words": 187, "dropped_gopher_above_avg_threshold": 3, "dropped_gopher_too_many_bullets": 25, "dropped_gopher_too_many_ellipsis": 22},
     "FineWeb Quality": {"total": 57863, "forwarded": 55756, "dropped": 2107, "doc_len": {"min":320, "max":141634, "avg":3628}, "dropped_char_dup_ratio": 606, "dropped_line_punct_ratio": 1393, "dropped_short_line_ratio": 108},
     "WRITER":{"total": 55756, "doc_len": {"min":320, "max":141634, "avg":3628}}
     },
   
   
   {"name":"haberler",
     "READER":{"total":892735, "doc_len":{"min":10734, "max":1020256, "avg":48859}},
     "EXTRAC":{"total": 892783, "forwarded": 878846,"dropped": 13911, "doc_len": {"min":100, "max":258580, "avg":2220}},
     "Gopher Repetition":{"total": 878846, "forwarded": 734576, "dropped": 144270, "doc_len": {"min":104, "max":226451, "avg":2261}, "dropped_duplicated_5_n_grams": 59161, "dropped_top_4_gram": 8209, "dropped_duplicated_10_n_grams": 11355, "dropped_duplicated_6_n_grams": 9535, "dropped_dup_line_char_frac": 12584, "dropped_top_2_gram": 6057, "dropped_top_3_gram": 3525, "dropped_duplicated_8_n_grams": 8091, "dropped_dup_line_frac": 8536, "dropped_duplicated_9_n_grams": 9380, "dropped_duplicated_7_n_grams": 7837},
     "Gopher Quality":{"total": 734576, "forwarded": 665046, "dropped": 69530, "doc_len": {"min":289, "max":226451, "avg":2357}, "dropped_gopher_enough_stop_words": 14315, "dropped_gopher_below_alpha_threshold": 20634, "dropped_gopher_short_doc": 30660, "dropped_gopher_too_many_end_ellipsis": 2642, "dropped_gopher_too_many_bullets": 1052, "dropped_gopher_too_many_hashes": 150, "dropped_gopher_above_avg_threshold": 31, "dropped_gopher_too_many_ellipsis": 38, "dropped_gopher_below_avg_threshold": 8},
     "FineWeb Quality": {"total": 665046, "forwarded": 552800, "dropped": 112246, "doc_len": {"min":303, "max":226451, "avg":2252}, "dropped_char_dup_ratio": 86642, "dropped_line_punct_ratio": 23060, "dropped_short_line_ratio": 2544},
     "WRITER":{"total": 552800, "doc_len": {"min":303, "max":226451, "avg":2252}}
     },
   
   
      
   {"name":"indyturk",
     "READER":{"total":87582, "doc_len":{"min":27284, "max":835222, "avg":78706}},
     "EXTRAC":{"total": 87670, "forwarded": 87616,"dropped": 50, "doc_len": {"min":101, "max":89259, "avg":3363}},
     "Gopher Repetition":{"total": 87616, "forwarded": 83679, "dropped": 3937, "doc_len": {"min":112, "max":89259, "avg":3472}, "dropped_duplicated_6_n_grams": 187, "dropped_duplicated_5_n_grams": 1180, "dropped_duplicated_10_n_grams": 159, "dropped_duplicated_7_n_grams": 146, "dropped_duplicated_9_n_grams": 139, "dropped_top_4_gram": 919, "dropped_dup_line_frac": 150, "dropped_duplicated_8_n_grams": 109, "dropped_top_3_gram": 712, "dropped_top_2_gram": 218, "dropped_dup_line_char_frac": 18},
     "Gopher Quality":{"total": 83679, "forwarded": 78176, "dropped": 5503, "doc_len": {"min":331, "max":89259, "avg":3681}, "dropped_gopher_below_alpha_threshold": 528, "dropped_gopher_short_doc": 4415, "dropped_gopher_too_many_end_ellipsis": 116, "dropped_gopher_enough_stop_words": 437, "dropped_gopher_too_many_ellipsis": 4, "dropped_gopher_too_many_hashes": 2, "dropped_gopher_too_many_bullets": 1},
     "FineWeb Quality": {"total": 78176, "forwarded": 74053, "dropped": 4123, "doc_len": {"min":342, "max":89259, "avg":3786}, "dropped_char_dup_ratio": 534, "dropped_short_line_ratio": 42, "dropped_line_punct_ratio": 3547},
     "WRITER":{"total": 74053, "doc_len": {"min":342, "max":89259, "avg":3786}}
     },
   
   
   {"name":"aa",
     "READER":{"total":161706, "doc_len":{"min":6627, "max":1037373, "avg":62935}},
     "EXTRAC":{"total": 161868, "forwarded": 128753,"dropped": 33115, "doc_len": {"min":105, "max":1028221, "avg":2994}},
     "Gopher Repetition":{"total": 128753, "forwarded": 112170, "dropped": 16583, "doc_len": {"min":171, "max":1028221, "avg":3080}, "dropped_duplicated_7_n_grams": 262, "dropped_duplicated_10_n_grams": 408, "dropped_duplicated_5_n_grams": 2600, "dropped_top_3_gram": 97, "dropped_duplicated_6_n_grams": 299, "dropped_duplicated_9_n_grams": 301, "dropped_top_4_gram": 386, "dropped_dup_line_frac": 11290, "dropped_duplicated_8_n_grams": 261, "dropped_dup_line_char_frac": 662, "dropped_top_2_gram": 17},
     "Gopher Quality":{"total": 112170, "forwarded": 108343, "dropped": 3827, "doc_len": {"min":340, "max":183554, "avg":3071}, "dropped_gopher_below_alpha_threshold": 1090, "dropped_gopher_enough_stop_words": 396, "dropped_gopher_short_doc": 2325, "dropped_gopher_too_many_ellipsis": 1, "dropped_gopher_above_avg_threshold": 13, "dropped_gopher_too_many_end_ellipsis": 2},
     "FineWeb Quality": {"total": 108343, "forwarded": 93280, "dropped": 15063, "doc_len": {"min":352, "max":183554, "avg":3107}, "dropped_char_dup_ratio": 1880, "dropped_line_punct_ratio": 13174, "dropped_short_line_ratio": 9},
     "WRITER":{"total": 93280, "doc_len": {"min":352, "max":183554, "avg":3107}}
     },
    
]

# %%
dedup_domain=[
    {"name":"tr_euronews", "total": 131181, "forwarded": 118458, "dropped": 12723},
    {"name":"ajltr", "total": 6707, "forwarded": 5671, "dropped": 1036},
    {"name":"t24","total": 273183, "forwarded": 256564, "dropped": 16619},
    {"name":"cnnturk", "total": 383255, "forwarded": 372928, "dropped": 10327},
    {"name":"dwtr", "total": 75902, "dropped": 3806, "forwarded": 72096},
    {"name":"sozcu", "total": 410445, "forwarded": 372947, "dropped": 37498},
    {"name":"yesil", "total": 55756, "forwarded": 47633, "dropped": 8123},
    {"name":"haberler", "total": 552800, "forwarded": 503607, "dropped": 49193},
    {"name":"indyturk", "total": 74053, "forwarded": 72804, "dropped": 1249},
    {"name":"aa", "total": 93280, "forwarded": 91949, "dropped": 1331}
    ]

# %%
dedup_all={"total": 1914657, "forwarded": 1845941, "dropped": 68716}

# %%
len(text_filter)
# Out:
# 10

# %%
extract_total_read = sum([doc["EXTRAC"]["total"] for doc in text_filter])
f'{extract_total_read:,}'
# Out:
# '3,068,443'

# %%
extract_total_drop = sum([doc["EXTRAC"]["dropped"] for doc in text_filter])
f'{extract_total_drop:,}'
# Out:
# '79,332'

# %%
grep_total_read = sum([doc["Gopher Repetition"]["total"] for doc in text_filter])
f'{grep_total_read:,}'
# Out:
# '2,986,596'

# %%
grep_total_drop = sum([doc["Gopher Repetition"]["dropped"] for doc in text_filter])
f'{grep_total_drop:,}'
# Out:
# '380,976'

# %%
gqual_total_read = sum([doc["Gopher Quality"]["total"] for doc in text_filter])
f'{gqual_total_read:,}'
# Out:
# '2,605,620'

# %%
gqual_total_drop = sum([doc["Gopher Quality"]["dropped"] for doc in text_filter])
f'{gqual_total_drop:,}'
# Out:
# '310,351'

# %%
fqual_total_read = sum([doc["FineWeb Quality"]["total"] for doc in text_filter])
f'{fqual_total_read:,}'
# Out:
# '2,295,269'

# %%
fqual_total_dropped = sum([doc["FineWeb Quality"]["dropped"] for doc in text_filter])
f'{fqual_total_dropped:,}'
# Out:
# '238,707'

# %%
total_write = sum([doc["WRITER"]["total"] for doc in text_filter])
f'{total_write:,}'
# Out:
# '2,056,562'

# %%
dedup_domain_dropped = sum([doc["dropped"] for doc in dedup_domain])
f'{dedup_domain_dropped:,}'
# Out:
# '141,905'

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# %%
labels = ['Extract','Gopher Repetition', 'Gopher Quality', 'Fineweb Quality', 'Dedup Domain','Dedup All',"Remained"]
sizes = [extract_total_drop, grep_total_drop, gqual_total_drop, fqual_total_dropped, dedup_domain_dropped, dedup_all['dropped'],dedup_all['forwarded']]

colors = ['#964B00', '#788F3C', '#6495ED', '#C9C4B5', '#8B9467', '#4682B4', '#FFC080', '#C0C0C0', '#708090', '#663300']

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%',radius=2.5, colors=colors)
plt.show()
